# %%
# !git clone https://github.com/maxon251191/PHC_MAMS.git
import os
os.chdir('PHC_MAMS')
print('Repo loaded!')

# %%
# !python scripts/download_data.py

# %%
import pandas as pd
df = pd.read_csv('data/wb_physicians_kz.csv')
df.head()
